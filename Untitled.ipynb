# %%
# %load_ext sql
# %sql mysql+mysqlconnector://root:Sakthi@localhost/

# %%
# %sql SHOW DATABASES
# Out:
#  * mysql+mysqlconnector://root:***@localhost/
# 6 rows affected.
# [('information_schema',),
#  ('mysql',),
#  ('performance_schema',),
#  ('sakila',),
#  ('sys',),
#  ('world',)]

# %%
# %%sql
# USE sakila
# Out:
#  * mysql+mysqlconnector://root:***@localhost/
# 0 rows affected.
# []

# %%
# %%sql
# SELECT DATABASE();
# Out:
#  * mysql+mysqlconnector://root:***@localhost/
# 1 rows affected.
# [('sakila',)]

# %%
# %%sql
# SHOW TABLES
# Out:
#  * mysql+mysqlconnector://root:***@localhost/
# 23 rows affected.
# [('actor',),
#  ('actor_info',),
#  ('address',),
#  ('category',),
#  ('city',),
#  ('country',),
#  ('customer',),
#  ('customer_list',),
#  ('film',),
#  ('film_actor',),
#  ('film_category',),
#  ('film_list',),
#  ('film_text',),
#  ('inventory',),
#  ('language',),
#  ('nicer_but_slower_film_list',),
#  ('payment',),
#  ('rental',),
#  ('sales_by_film_category',),
#  ('sales_by_store',),
#  ('staff',),
#  ('staff_list',),
#  ('store',)]

# %%
# %sql SHOW DATABASES
# Out:
#  * mysql+mysqlconnector://root:***@localhost/
# 6 rows affected.
# [('information_schema',),
#  ('mysql',),
#  ('performance_schema',),
#  ('sakila',),
#  ('sys',),
#  ('world',)]

# %%
# %%sql
# USE world;
#
# SHOW TABLES;
# DESCRIBE country;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/
# 0 rows affected.
# 3 rows affected.
# 15 rows affected.
# [('Code', 'char(3)', 'NO', 'PRI', '', ''),
#  ('Name', 'char(52)', 'NO', '', '', ''),
#  ('Continent', "enum('Asia','Europe','North America','Africa','Oceania','Antarctica','South America')", 'NO', '', 'Asia', ''),
#  ('Region', 'char(26)', 'NO', '', '', ''),
#  ('SurfaceArea', 'decimal(10,2)', 'NO', '', '0.00', ''),
#  ('IndepYear', 'smallint', 'YES', '', None, ''),
#  ('Population', 'int', 'NO', '', '0', ''),
#  ('LifeExpectancy', 'decimal(3,1)', 'YES', '', None, ''),
#  ('GNP', 'decimal(10,2)', 'YES', '', None, ''),
#  ('GNPOld', 'decimal(10,2)', 'YES', '', None, ''),
#  ('LocalName', 'char(45)', 'NO', '', '', ''),
#  ('GovernmentForm', 'char(45)', 'NO', '', '', ''),
#  ('HeadOfState', 'char(60)', 'YES', '', None, ''),
#  ('Capital', 'int', 'YES', '', None, ''),
#  ('Code2', 'char(2)', 'NO', '', '', '')]

# %%
# %sql SHOW TABLES;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/
# 3 rows affected.
# [('city',), ('country',), ('countrylanguage',)]

# %%
# %%sql
# CREATE DATABASE college;
# USE college;
# SELECT DATABASE();
# Out:
#  * mysql+mysqlconnector://root:***@localhost/
# 1 rows affected.
# 0 rows affected.
# 1 rows affected.
# [('college',)]

# %%
# %%sql
# show databases;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/
# 7 rows affected.
# [('college',),
#  ('information_schema',),
#  ('mysql',),
#  ('performance_schema',),
#  ('sakila',),
#  ('sys',),
#  ('world',)]

# %%
# %%sql
# use world
# Out:
#  * mysql+mysqlconnector://root:***@localhost/
# 0 rows affected.
# []

# %%
# %%sql
# use college
# Out:
#  * mysql+mysqlconnector://root:***@localhost/
# 0 rows affected.
# []

# %%
# %%sql
# select database();
# Out:
#  * mysql+mysqlconnector://root:***@localhost/
# 1 rows affected.
# [('college',)]

# %%
# %%sql
# create tablE stud (id INT PRIMARY KEY , NAME VARCHAR(100) , PHONE INT);
# Out:
#  * mysql+mysqlconnector://root:***@localhost/
# (mysql.connector.errors.ProgrammingError) 1050 (42S01): Table 'stud' already exists
# [SQL: create tablE stud (id INT PRIMARY KEY , NAME VARCHAR(100) , PHONE INT);]
# (Background on this error at: https://sqlalche.me/e/20/f405)

# %%
# %%sql
# INSERT INTO STUD ( ID , NAME , PHONE) VALUES ( 1 , "SA" , 3444 ),(2 , "GH", 7890);
# SELECT * FROM STUD;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/
# 2 rows affected.
# 2 rows affected.
# [(1, 'SA', 3444), (2, 'GH', 7890)]

# %%
# %%sql
# SELECT * FROM stud;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/
# 2 rows affected.
# [(1, 'SA', 3444), (2, 'GH', 7890)]

# %%
# %%sql
# select id name, phone  from stud;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/
# 2 rows affected.
# [(1, 3444), (2, 7890)]

# %%
# %%sql
# insert into stud ( id , name )values ( 3 , "sak" ) , (4,"uuu");
# select * from stud;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/
# 2 rows affected.
# 4 rows affected.
# [(1, 'SA', 3444), (2, 'GH', 7890), (3, 'sak', None), (4, 'uuu', None)]

# %%
# %%sql
# SELECT * FROM stud;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/
# 2 rows affected.
# [(1, 'SA', 3444), (2, 'GH', 7890)]

# %%
# %%sql
# update stud set name = "gowtham" ;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/
# 4 rows affected.
# []

# %%
# %%sql
#
# select * from stud
# Out:
#  * mysql+mysqlconnector://root:***@localhost/
# 4 rows affected.
# [(1, 'gowtham', 3444),
#  (2, 'gowtham', 7890),
#  (3, 'gowtham', None),
#  (4, 'gowtham', None)]
